# %%
from splinter import Browser
from bs4 import BeautifulSoup
import pandas as pd
import datetime as dt
import requests

# %%
executable_path = {'executable_path': '../chromedriver.exe'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
url = 'https://www.nasa.gov/missions/'
html = browser.visit(url)

# %%
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# %%
pages = soup.find('div', class_="static-landing-page").a.find_all_next(string=True)

# %%
dirty_mission_list = pages

# %%
clean_mission_list =

# %%
pages.find()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-ca2ab69d8758> in <module>()
# ----> 1 pages.find()
#
# ~\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1805     def __getattr__(self, key):
#    1806         raise AttributeError(
# -> 1807             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1808         )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?

# %%
url = 'https://www.nasa.gov/missions/'
html = browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')

# Stiring the soup
links = [a for a in soup.find('div', class_="static-landing-page").find_all('a', href = True)]

# Pouring out the list and title
link_list = []
title_list = []
for i in range(len(links)):
    if links[i].get('href').find("mission_pages") == 1:
        link_list.append(links[i]['href'])
        title_list.append(links[i].text)
    else:
            print('No Mission Page')
mission_dict = {}
mission_dict["Mission"] = title_list
mission_dict["Mission Link"] = link_list             

url = 'https://www.cdscc.nasa.gov/Pages/trackingtoday.html'
html = browser.visit(url)
html = browser.html
soup = BeautifulSoup(html, 'html.parser')       
abv_table = pd.read_html(url)[3] 

abv_table.columns = ['ABV', 'Name']         
abv_dict = abv_table.to_dict("records")

# Platting the soup            
mission_data = {
    "Mission titles" : mission_dict,
    "Mission Code" : abv_dict
    } 
browser.quit           
print(mission_data)
# Out:
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# No Mission Page
# {'Mission titles': {'Mission': ['AIM', 'Apollo', 'Apollo-Soyuz', 'Aqua', 'Aquarius', 'ARCTAS', 'ARTEMIS', 'Astro-E2 (Suzaku)', 'Aura', 'CALIPSO', 'Cassini-Huygens', 'Chandra X-Ray Observatory', 'CINDI', 'Cloudsat', 'Commercial Resupply Services', 'CubeSats', 'Curiosity', 'Dawn', 'Deep Impact', 'DISCOVER-AQ', 'ECOSTRESS', 'EPOXI\u200b', 'Euclid', 'Explorer', 'Fermi Gamma-ray Space Telescope', 'Fire and Smoke', 'GALEX', 'Gemini', 'Genesis', 'GLAST', 'Global Precipitation Measurement (GPM)', 'Glory', 'GRAIL', 'Gravity Probe-B', 'Herschel', 'Heliophysics', 'Hinode (Solar-b)', 'Hubble', 'Hurricanes', 'IBEX (Interstellar Boundary Explorer)', 'International Space Station', 'IRIS (Interface Region Imaging Spectrograph)', 'James Webb Space Telescope', 'Juno', 'Kepler and K2', 'LADEE: Lunar Atmosphere Dust Environment Explorer', 'Landsat Data Continuity Mission', 'LCROSS', 'Low-Boom Flight Demonstration', 'LRO (Lunar Reconnaissance Orbiter)', 'Lunar Quest Program', 'Magnetospheric Multiscale (MMS)', 'Mariner', 'Mars Exploration Rovers (Spirit and Opportunity)', 'Mars Global Surveyor', 'Mars Odyssey', 'Mars Pathfinder', 'Mars Reconnaissance Orbiter', 'Mars Science Laboratory (Curiosity)', 'MAVEN: Mars Atmosphere and Volatile EvolutioN', 'Mercury\xa0(Human Spaceflight Program)', 'MESSENGER: Mercury, Surface, Space Environment, Geochemistry and Ranging', 'Mini-RF', 'NEOWISE', 'New Horizons', 'NOAA-N', 'NOAA-N Prime', 'NPP', 'NuSTAR', 'Ocean Surface Topography Mission/Jason 2', 'Orbiting Carbon Observatory-2', 'OSIRIS-REx', 'Phoenix', 'Pioneer', 'Pioneer Venus', 'Planck', 'Radiation Belt Storm Probes/Van Allen Probes', 'SDO (Solar Dynamics Observatory)', 'SEAC4RS', 'SERVIR', 'Shuttle-Mir', 'Skylab', 'Small Satellites', 'SOFIA', 'SOHO', 'Sounding Rockets', 'Space Shuttle', 'Space Station', 'Spitzer', 'Stardust-NExT', 'STEREO', 'Suomi NPP', 'Suzaku', 'Swift', 'TDRS (Tracking and Data Relay Satellites)', 'Terra', 'THEMIS', 'Upper Atmosphere Radiation Satellite (UARS)', 'Van Allen Probes', 'Voyager', 'Wide-Field Infrared Survey Explorer (WISE)'], 'Mission Link': ['/mission_pages/aim/index.html', '/mission_pages/apollo', '/mission_pages/apollo-soyuz/index.html', '/mission_pages/aqua/index.html', '/mission_pages/aquarius/main/index.html', '/mission_pages/arctas/', '/mission_pages/artemis/index.html', '/mission_pages/astro-e2/main/index.html', '/mission_pages/aura/main/index.html', '/mission_pages/calipso/main/index.html', '/mission_pages/cassini/main/index.html', '/mission_pages/chandra/main/index.html', '/mission_pages/cindi/', '/mission_pages/cloudsat/main/index.html', '/mission_pages/station/structure/launch/index.html', '/mission_pages/cubesats/index.html', '/mission_pages/msl/index.html', '/mission_pages/dawn/main/index.html', '/mission_pages/deepimpact/main/index.html', '/mission_pages/discover-aq/', '/mission_pages/ecostress', '/mission_pages/epoxi/index.html', '/mission_pages/euclid/main/index.html', '/mission_pages/explorer/index.html', '/mission_pages/GLAST/main/index.html', '/mission_pages/fires/main/index.html', '/mission_pages/galex/index.html', '/mission_pages/gemini/index.html', '/mission_pages/genesis/main/index.html', '/mission_pages/GLAST/main/index.html', '/mission_pages/GPM/main/index.html', '/mission_pages/Glory/main/index.html', '/mission_pages/grail/main/index.html', '/mission_pages/gpb/index.html', '/mission_pages/herschel/index.html', '/mission_pages/sunearth/index.html', '/mission_pages/solar-b/index.html', '/mission_pages/hubble/main/index.html', '/mission_pages/hurricanes/main/index.html', '/mission_pages/ibex/index.html', '/mission_pages/station/main/index.html', '/mission_pages/iris/index.html', '/mission_pages/webb/main/index.html', '/mission_pages/juno/main/index.html', '/mission_pages/kepler/main/index.html', '/mission_pages/LADEE/main/', '/mission_pages/landsat/main/index.html', '/mission_pages/LCROSS/main/', '/mission_pages/lowboom/index.html', '/mission_pages/LRO/main/index.html', '/mission_pages/lunarquest/mai ...

# %%
import pandas as pd
from flask import Flask, jsonify, render_template, request, redirect
from flask_pymongo import PyMongo
import scrape_nasa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-5edcaf4a9a45> in <module>()
#       2 from flask import Flask, jsonify, render_template, request, redirect
#       3 from flask_pymongo import PyMongo
# ----> 4 import scrape_nasa
#
# ModuleNotFoundError: No module named 'scrape_nasa'

# %%
app = Flask(__name__)

mongo = PyMongo(app, uri="mongodb://localhost:27017/nasa_app")

# %%
mission = abv_dict.scrape_info()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-b610e8fbc112> in <module>()
# ----> 1 mission = abv_dict.scrape_info()
#
# AttributeError: 'list' object has no attribute 'scrape_info'

# %%
mission_data
# Out:
# {'Mission titles': {'Mission': ['AIM',
#    'Apollo',
#    'Apollo-Soyuz',
#    'Aqua',
#    'Aquarius',
#    'ARCTAS',
#    'ARTEMIS',
#    'Astro-E2 (Suzaku)',
#    'Aura',
#    'CALIPSO',
#    'Cassini-Huygens',
#    'Chandra X-Ray Observatory',
#    'CINDI',
#    'Cloudsat',
#    'Commercial Resupply Services',
#    'CubeSats',
#    'Curiosity',
#    'Dawn',
#    'Deep Impact',
#    'DISCOVER-AQ',
#    'ECOSTRESS',
#    'EPOXI\u200b',
#    'Euclid',
#    'Explorer',
#    'Fermi Gamma-ray Space Telescope',
#    'Fire and Smoke',
#    'GALEX',
#    'Gemini',
#    'Genesis',
#    'GLAST',
#    'Global Precipitation Measurement (GPM)',
#    'Glory',
#    'GRAIL',
#    'Gravity Probe-B',
#    'Herschel',
#    'Heliophysics',
#    'Hinode (Solar-b)',
#    'Hubble',
#    'Hurricanes',
#    'IBEX (Interstellar Boundary Explorer)',
#    'International Space Station',
#    'IRIS (Interface Region Imaging Spectrograph)',
#    'James Webb Space Telescope',
#    'Juno',
#    'Kepler and K2',
#    'LADEE: Lunar Atmosphere Dust Environment Explorer',
#    'Landsat Data Continuity Mission',
#    'LCROSS',
#    'Low-Boom Flight Demonstration',
#    'LRO (Lunar Reconnaissance Orbiter)',
#    'Lunar Quest Program',
#    'Magnetospheric Multiscale (MMS)',
#    'Mariner',
#    'Mars Exploration Rovers (Spirit and Opportunity)',
#    'Mars Global Surveyor',
#    'Mars Odyssey',
#    'Mars Pathfinder',
#    'Mars Reconnaissance Orbiter',
#    'Mars Science Laboratory (Curiosity)',
#    'MAVEN: Mars Atmosphere and Volatile EvolutioN',
#    'Mercury\xa0(Human Spaceflight Program)',
#    'MESSENGER: Mercury, Surface, Space Environment, Geochemistry and Ranging',
#    'Mini-RF',
#    'NEOWISE',
#    'New Horizons',
#    'NOAA-N',
#    'NOAA-N Prime',
#    'NPP',
#    'NuSTAR',
#    'Ocean Surface Topography Mission/Jason 2',
#    'Orbiting Carbon Observatory-2',
#    'OSIRIS-REx',
#    'Phoenix',
#    'Pioneer',
#    'Pioneer Venus',
#    'Planck',
#    'Radiation Belt Storm Probes/Van Allen Probes',
#    'SDO (Solar Dynamics Observatory)',
#    'SEAC4RS',
#    'SERVIR',
#    'Shuttle-Mir',
#    'Skylab',
#    'Small Satellites',
#    'SOFIA',
#    'SOHO',
#    'Sounding Rockets',
#    'Space Shuttle',
#    'Space Station',
#    'Spitzer',
#    'Stardust-NExT',
#    'STEREO',
#    'Suomi NPP',
#    'Suzaku',
#    'Swift',
#    'TDRS (Tracking and Data Relay Satellites)',
#    'Terra',
#    'THEMIS',
#    'Upper Atmosphere Radiation Satellite (UARS)',
#    'Van Allen Probes',
#    'Voyager',
#    'Wide-Field Infrared Survey Explorer (WISE)'],
#   'Mission Link': ['/mission_pages/aim/index.html',
#    '/mission_pages/apollo',
#    '/mission_pages/apollo-soyuz/index.html',
#    '/mission_pages/aqua/index.html',
#    '/mission_pages/aquarius/main/index.html',
#    '/mission_pages/arctas/',
#    '/mission_pages/artemis/index.html',
#    '/mission_pages/astro-e2/main/index.html',
#    '/mission_pages/aura/main/index.html',
#    '/mission_pages/calipso/main/index.html',
#    '/mission_pages/cassini/main/index.html',
#    '/mission_pages/chandra/main/index.html',
#    '/mission_pages/cindi/',
#    '/mission_pages/cloudsat/main/index.html',
#    '/mission_pages/station/structure/launch/index.html',
#    '/mission_pages/cubesats/index.html',
#    '/mission_pages/msl/index.html',
#    '/mission_pages/dawn/main/index.html',
#    '/mission_pages/deepimpact/main/index.html',
#    '/mission_pages/discover-aq/',
#    '/mission_pages/ecostress',
#    '/mission_pages/epoxi/index.html',
#    '/mission_pages/euclid/main/index.html',
#    '/mission_pages/explorer/index.html',
#    '/mission_pages/GLAST/main/index.html',
#    '/mission_pages/fires/main/index.html',
#    '/mission_pages/galex/index.html',
#    '/mission_pages/gemini/index.html',
#    '/mission_pages/genesis/main/index.html',
#    '/mission_pages/GLAST/main/index.html',
#    '/mission_pages/GPM/main/index.html',
#    '/mission_pages/Glory/main/index.html',
#    '/mission_pages/grail/main/index.html',
#    '/mission_pages/gpb/index.html',
#    '/mission_pages/herschel/index.html',
#    '/mission_pages/sunearth/index.html',
#    '/mission_pages/solar-b/index.html',
#    '/mission_pages/hubble/main/index.html',
#    '/mission_pages/hurricanes/main/index.html',
#    '/mission_pages/ibex/index.html',
#    '/mission_pages/station/main/index.html',
#    '/mission_pages/iris/index.html',
#    '/mission_pages/webb/main/index.html',
#    '/mission_pages/juno/main/index.html',
#    '/mission_pages/kepler/main/index.html',
#    '/mission_pages/LADEE/main/',
#    '/mission_pages/landsat/main/index.html',
#    '/mission_pages/LCROSS/main/',
#    '/mission_pages/lowboom/index.html',
#    '/mission_pages/LRO/main/index.html',
#    '/mission_pages/lunarquest/main/index.html',
#    '/mission_pages/mms/index.html',
#    '/mission_pages/mariner',
#    '/mission_pages/mer/index.html',
#    '/mission_pages/mgs/index.html',
#    '/mission_pages/odyssey/index.html',
#    '/mission_pages/mars-pathfinder/index.html',
#    '/mission_pages/MRO/main/index.html',
#    '/mission_pages/msl/index.html',
#    '/mission_pages/maven/main/index.html',
#    '/mission_pages/mercury/index.html',
#    '/mission_pages/messenger/main/index.html',
#    '/mission_pages/Mini-RF/main/index.html',
#    '/mission_pages/neowise/main/index.html',
#    '/mission_pages/newhorizons/main/index.html',
#    '/mission_pages/noaa-n/main/index.html',
#    '/mission_pages/NOAA-N-Prime/main/index.html',
#    '/mission_pages/NPP/main/index.html',
#    '/mission_pages/nustar/main/index.html',
#    '/mission_pages/ostm/main/index.html',
#    '/mission_pages/oco2/index.html',
#    '/mission_pages/osiris-rex/index.html',
#    '/mission_pages/phoenix/main/index.html',
#    '/mission_pages/pioneer/index.html',
#    '/mission_pages/pioneer-venus/index.html',
#    '/mission_pages/planck/index.html',
#    '/mission_pages/rbsp/main/index.html',
#    '/mission_pages/sdo/main/index.html',
#    '/mission_pages/seac4rs/index.html',
#    '/mission_pages/servir/index.html',
#    '/mission_pages/shuttle-mir/index.html',
#    '/mission_pages/skylab/index.html',
#    '/mission_pages/smallsats/',
#    '/mission_pages/SOFIA/index.html',
#    '/mission_pages/soho/index.html',
#    '/mission_pages/sounding-rockets/index.html',
#    '/mission_pages/shuttle/main/index.html',
#    '/mission_pages/station/main/index.html',
#    '/mission_pages/spitzer/main/index.html',
#    '/mission_pages/stardust/main/index.html',
#    '/mission_pages/stereo/main/index.html',
#    '/mission_pages/NPP/main/index.html',
#    '/mission_pages/astro-e2/main/index.html',
#    '/mission_pages/swift/main/index.html',
#    '/mission_pages/tdrs/home/index.html',
#    '/mission_pages/terra/index.html',
#    '/mission_pages/themis/main/index.html',
#    '/mission_pages/uars/',
#    '/mission_pages/rbsp/main/index.html',
#    '/mission_pages/voyager/index.html',
#    '/mission_pages/WISE/main/index.html']}}
